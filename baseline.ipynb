# %% [markdown]
# ## Data acquisition and analysis
#
# ### Aquisition
# The source we use for the pictures: https://www.kaggle.com/datasets/kacpergregorowicz/house-plant-species?resource=download
# From here, we have chosen the following type of plants: Aloe_Vera, Chienese_Money_Plant, Elephant_Ear
#
# • After downloading each of them into a different directory, their name was 1.jpg, 2.jpg, etc.
# We wanted to store all of them in the same directory, so to handle this we needed to rename them. Thats why they got the names of Aloe_Vera_n.jpg, Elephant_Eat_n.jpg, etc.
#
# • Also, they had other extensions: jpg, jpeg, png, JPG, webp. We chosed to accept the first 4.
#
# • After the pictures was in the right place and structure, we generated a labels.csv that store the 'image names' and 'the claster they belong to' in a row.

# %%
# !pip install -q pandas
# !pip install -q Pillow
# !pip install -q matplotlib
# !pip install -q torch
# !pip install -q torchvision
# !pip install -q pytorch_lightning
# !pip install -q torchmetrics

# %%
import torch
import torch.nn.functional as F
import torchvision
from torchvision import transforms
import pytorch_lightning as pl
import torchmetrics
import matplotlib.pyplot as plt
import wandb
import pandas as pd
from PIL import Image
import os
from torch.utils.data import Dataset
from torchvision.io import read_image
from torch.utils.data import random_split
from torch.utils.data import DataLoader
import random
from torchvision.io import read_image

# %%
random.seed(42)
#directory = 'D:\\BME\\_MSC\\2_felev\\DL\\'
directory = 'images'
labels_file_path = 'labels.csv'
# directory = '/app/images'
# labels = '/app/labels.csv'

# %%
files = os.listdir(directory)
ratios = []
classes = {"aloe_vera": 0, "chinese_money_plant": 0, "elephant_ear": 0}
# Iterate through each file
for file in files:
    if file.endswith(".jpg") or file.endswith(".jpeg") or file.endswith(".png") or file.endswith(".JPG"):
        # Open the image
        try:
            with Image.open(os.path.join(directory, file)) as img:
                name = '_'.join(file.split('_')[:-1])
                if name == 'Aloe_Vera':
                    classes["aloe_vera"] += 1
                elif name == 'Chinese_Money_Plant':
                    classes["chinese_money_plant"] += 1
                elif name == 'Elephant_Ear':
                    classes["elephant_ear"] += 1
                # Get original dimensions
                width, height = img.size
                ratio = width / height
                ratios.append(ratio)

        except Exception as inst:
            print(file + "could not be opened")
            continue
        finally:
            img.close()

    else:
        print(f"Skipping {file}: Not the expected extension")


occurrences = {item: ratios.count(item) for item in ratios}
# Out:
# Skipping Elephant_Ear_24.webp: Not the expected extension
# Skipping Chinese_Money_Plant_75.webp: Not the expected extension
# Skipping Chinese_Money_Plant_339.Jpg: Not the expected extension
# Skipping Elephant_Ear_159.webp: Not the expected extension
# Skipping Elephant_Ear_99.webp: Not the expected extension
# Skipping Elephant_Ear_191.webp: Not the expected extension
# Skipping Aloe_Vera_75.webp: Not the expected extension
# Skipping Chinese_Money_Plant_60.Jpg: Not the expected extension
# Skipping Aloe_Vera_42.webp: Not the expected extension
# Skipping Elephant_Ear_222.webp: Not the expected extension
# Skipping Aloe_Vera_185.jpe: Not the expected extension
# Skipping Elephant_Ear_330.webp: Not the expected extension
# Skipping Elephant_Ear_29.webp: Not the expected extension
# Skipping Aloe_Vera_132.webp: Not the expected extension
# Skipping Aloe_Vera_187.webp: Not the expected extension

# %% [markdown]
# ### Analysis
#
# 1) We have calculated the ratio of the pictures, and searched for the most common ones in the dataset.
# The following histogram plots it: 1.0 is the most common, that is why we decided to use it as default. Our oppinion is that if a picture is a bit misshapen that does not affect the solution. We tested the ideal for this margin of error and keep the pictures between 0.6 and 1.2 ratio. (To have enough of them for training.)

# %%
# Extracting keys and values
keys = list(occurrences.keys())
values = list(occurrences.values())

# Plotting the histogram
plt.bar(keys, values, width=0.01)
plt.xlabel('Ratio')
plt.ylabel('Count')
plt.title('Histogram of image ratios')
plt.show()

# as it seen in the histogram, the most common type is 1.0, and around that -> so we choose to convert the images into 1:1 ratio

# %%
# Extracting keys and values
keys = list(classes.keys())
values = list(classes.values())

# Plotting the histogram
plt.bar(keys, values, width=0.01)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Class counts')
plt.show()

# %% [markdown]
# ### Data cleaning and preparation
#
# 1) For preparation, we resized each of the pictures to the same. It has 1.0 ratio as we earlier discussed. We would like to pick a number of pixels below 100. (This ensures, that the training won't be extremely slow.)
# For cleaning, we dropped the ones where the ratio was under 0.6 or above 1.2, so where it was not fit into the condition we assigned to keeping them.

# %%
files = os.listdir(directory)
df = pd.DataFrame(columns=['Id', 'Label'])
for file in files:
  if file.endswith(".jpg") or file.endswith(".jpeg") or file.endswith(".png") or file.endswith(".JPG"):
    # Open the image
    try:
      with Image.open(os.path.join(directory, file)) as img:
        img.verify()
        # Get original dimensions
        width, height = img.size
        ratio = width / height
        if ratio > 0.6 and ratio < 1.2:
          dictionary={}
          name = '_'.join(file.split('_')[:-1])
          if name == 'Aloe_Vera':
            cl = 0
          elif name == 'Chinese_Money_Plant':
            cl = 1
          elif name == 'Elephant_Ear':
            cl = 2
          dictionary['Id'] = file
          dictionary['Label'] = cl
          new_row = pd.DataFrame([dictionary])
          df = pd.concat([df, new_row], ignore_index=True)
        else:
          print(f"Skipping {file}: Dimensions ratio do not match (expected between 0.6 and 1.2)")

    except IOError as inst:
      print(file + f"could not be opened:{inst}")
      os.remove(os.path.join(directory, file))
      continue


  else:
    print(f"Skipping {file}: Not the expected extension")

df.to_csv(labels_file_path, index=False)
# Out:
# Skipping Elephant_Ear_67.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_155.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_200.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_33.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_149.jpeg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_283.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_79.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_136.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_57.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_58.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_214.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_125.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_103.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_133.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_178.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_289.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_51.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_231.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_62.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_48.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_24.webp: Not the expected extension
# Skipping Elephant_Ear_304.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_235.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_52.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_171.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_192.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_219.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_75.webp: Not the expected extension
# Skipping Aloe_Vera_98.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_188.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_104.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_136.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_216.JPG: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_76.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_53.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_316.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_19.png: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_84.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_317.png: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_109.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_226.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_322.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_176.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_245.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_361.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_103.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_209.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_339.Jpg: Not the expected extension
# Skipping Aloe_Vera_247.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_111.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_55.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_214.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_368.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_105.png: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_151.jpeg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_17.png: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_16.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_140.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_105.JPG: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_114.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_287.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_38.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_7.jpeg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_181.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_92.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_254.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_159.webp: Not the expected extension
# Skipping Aloe_Vera_26.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_74.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_5.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_9.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_99.webp: Not the expected extension
# Skipping Chinese_Money_Plant_288.JPG: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_68.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_216.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_8.jpeg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_174.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_59.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_325.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_279.jpeg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_200.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_26.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_167.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_153.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_98.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_272.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_263.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_116.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_20.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_44.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_56.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_55.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_274.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_380.jpeg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_288.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_90.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_311.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_13.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_34.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_12.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_255.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_161.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_245.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_377.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_67.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_33.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_50.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_160.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_249.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_163.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_55.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_97.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_236.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_349.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_27.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_236.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_78.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_15.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_198.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_148.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_313.jpeg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_60.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_108.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_180.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_118.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_142.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_293.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_38.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_120.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_88.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_37.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_231.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_208.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_2.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_181.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_183.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_164.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_119.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_174.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_160.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_138.jpeg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_325.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_301.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_359.jpeg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_115.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_167.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_87.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_49.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_203.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_64.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_118.png: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_56.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_84.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_286.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_45.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_81.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_278.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_193.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_23.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_191.webp: Not the expected extension
# Skipping Chinese_Money_Plant_114.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_280.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_3.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_73.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_49.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_287.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_34.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_163.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_191.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_316.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_82.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_6.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_31.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_378.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_25.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_189.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_331.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_305.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_326.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_206.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_46.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_72.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_39.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_190.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_194.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_75.webp: Not the expected extension
# Skipping Elephant_Ear_307.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_60.Jpg: Not the expected extension
# Skipping Aloe_Vera_160.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_70.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_97.JPG: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_363.JPG: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_67.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_381.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_149.jpeg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_270.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_93.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_42.webp: Not the expected extension
# Skipping Elephant_Ear_257.png: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_29.png: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_230.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_222.webp: Not the expected extension
# Skipping Elephant_Ear_318.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_308.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_17.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_212.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_49.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_282.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_14.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_236.jpeg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_276.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_185.jpe: Not the expected extension
# Skipping Elephant_Ear_65.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_251.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_226.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_330.webp: Not the expected extension
# Skipping Aloe_Vera_62.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_29.webp: Not the expected extension
# Skipping Elephant_Ear_75.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_308.jpeg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_132.webp: Not the expected extension
# Skipping Aloe_Vera_19.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_13.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_193.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_237.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_242.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_129.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_241.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_327.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_244.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_70.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_208.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_332.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_137.png: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_134.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_108.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_261.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_199.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_134.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_244.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_258.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_248.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_205.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_140.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_22.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_141.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_104.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_187.webp: Not the expected extension
# Skipping Chinese_Money_Plant_169.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_184.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_282.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_239.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_101.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_179.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_222.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_63.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_277.png: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_187.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_342.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_195.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_259.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_91.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_176.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_87.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Elephant_Ear_102.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_178.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_37.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Aloe_Vera_166.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_119.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)
# Skipping Chinese_Money_Plant_239.jpg: Dimensions ratio do not match (expected between 0.6 and 1.2)

# %%
resolution = 80
num_classes = 3
batch_size = 32
num_workers = 0

num_epochs = 5
num_epochs_baseline = 10
learning_rate = 3e-4
weight_decay = 1e-4
width = 64

# %%
class PlantImageDataset(Dataset):
    def __init__(self, img_dir, labels_file, transform):
        _labels = pd.read_csv(labels_file)
        self.img_labels = _labels
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, f'{self.img_labels.iloc[idx, 0]}')
        image = Image.open(img_path).convert('RGB')
        #image = read_image(img_path)
        if self.transform is not None:
            try:
                image = self.transform(image)
            except Exception as error:
                print(error)
        label = self.img_labels.iloc[idx, 1]
        return image, label

# %%
class SubsetWithTransform(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __len__(self):
        return len(self.subset)

    def __getitem__(self, idx):
        img, label = self.subset[idx]
        if self.transform:
            img = self.transform(img)
        return img, label

# %%
pds = PlantImageDataset(directory, labels_file_path, transform=transforms.Compose([
            transforms.RandomResizedCrop(size=resolution, scale=(0.75, 1.0), antialias=True),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor()]))
generator1 = torch.Generator().manual_seed(42)
splits = random_split(pds, [0.8, 0.1, 0.1], generator=generator1)
trainloader = (DataLoader(pds, batch_size=batch_size, shuffle=True))
valloader = (DataLoader(splits[1], batch_size=batch_size))
testloader = (DataLoader(splits[2], batch_size=batch_size))

# %%
mean = torch.zeros(3)
std = torch.zeros(3)
nb_samples = 0.0

for data, _ in trainloader:
    batch_samples = data.size(0)
    data = data.view(batch_samples, data.size(1), -1)
    mean += data.mean(2).sum(0)
    std += data.std(2).sum(0)
    nb_samples += batch_samples

mean /= nb_samples
std /= nb_samples

# %%
mean, std
# Out:
# (tensor([0.5452, 0.5786, 0.4690]), tensor([0.2294, 0.2116, 0.2503]))

# %%
class PlantsDataModule(pl.LightningDataModule):
    def __init__(self):
        super().__init__()
        self.train_transform = transforms.Compose([
            transforms.RandomResizedCrop(size=resolution, scale=(0.75, 1.0), antialias=True),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(mean=mean, std=std),
        ])
        self.val_transform = transforms.Compose([
            transforms.Resize(size=resolution, antialias=True),
            transforms.CenterCrop(size=resolution),
            transforms.ToTensor(),
            transforms.Normalize(mean=mean, std=std),
        ])

    # def preprocess_train(self, batch):
    #     batch["image"] = [self.train_transform(image) for image in batch["image"]]
    #     return batch

    # def preprocess_val(self, batch):
    #     batch["image"] = [self.val_transform(image) for image in batch["image"]]
    #     return batch

    def setup(self, stage=None):
        pds = PlantImageDataset(directory, labels_file_path, None)
        #pds = PlantImageDataset(directory, labels_file_path, self.train_transform)
        generator1 = torch.Generator().manual_seed(42)
        splits = random_split(pds, [0.8, 0.1, 0.1], generator=generator1)
        #self.train_dataset = pds
        self.train_dataset = SubsetWithTransform(splits[0], self.train_transform)
        self.val_dataset = SubsetWithTransform(splits[1], self.val_transform)
        self.test_dataset = SubsetWithTransform(splits[2], self.val_transform)

    def train_dataloader(self):
        return torch.utils.data.DataLoader(
            self.train_dataset,
            batch_size=batch_size,
            num_workers=num_workers,
            pin_memory=True,
            drop_last=True,
            shuffle=True,
        )

    def val_dataloader(self):
        return torch.utils.data.DataLoader(
            self.val_dataset,
            batch_size=batch_size,
            num_workers=num_workers,
            pin_memory=True,
        )

    def test_dataloader(self):
        return torch.utils.data.DataLoader(
            self.test_dataset,
            batch_size=batch_size,
            num_workers=num_workers,
            pin_memory=True,
        )

# %%
datamodule = PlantsDataModule()
datamodule.setup()

# %%
class ImageClassifier(pl.LightningModule):
    def __init__(self, model):
        super().__init__()
        self.model = model
        self.accuracy = torchmetrics.Accuracy(task="multiclass", num_classes=num_classes)
        self.confusionmatrix = torchmetrics.classification.MulticlassConfusionMatrix(num_classes=num_classes)
        self.per_class_accuracy = torchmetrics.Accuracy(task="multiclass", num_classes=num_classes, average="none")

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        #pred_labels = self(batch["image"])
        pred_labels = self(batch[0])

        # loss = F.cross_entropy(pred_labels, batch["label"])
        # accuracy = self.accuracy(pred_labels, batch["label"])
        loss = F.cross_entropy(pred_labels, batch[1])
        accuracy = self.accuracy(pred_labels, batch[1])

        self.log("train_loss", loss, on_epoch=True)
        self.log("train_acc", accuracy, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        pred_labels = self(batch[0])

        #calculating metrics
        loss = F.cross_entropy(pred_labels, batch[1])
        accuracy = self.accuracy(pred_labels, batch[1])
        confusionmatrix = self.confusionmatrix(pred_labels, batch[1])
        per_class_acc = self.per_class_accuracy(pred_labels, batch[1])

        #logging metrics
        for i in range(num_classes):
            self.log(f'val_acc_class_{i}', per_class_acc[i], prog_bar=True)
        self.log("val_loss", loss, prog_bar=True)
        self.log("val_acc", accuracy, prog_bar=True)



        return {"val_loss": loss}


    def test_step(self, batch, batch_idx):
        images, labels = batch
        pred_labels = self(images)

        loss = F.cross_entropy(pred_labels, labels)
        accuracy = self.accuracy(pred_labels, labels)

        self.log("test_loss", loss)
        self.log("test_acc", accuracy)
        return loss

    def configure_optimizers(self):
        #return torch.optim.Adam(self.parameters(), lr=learning_rate)
        return torch.optim.AdamW(self.parameters(), lr=learning_rate, weight_decay=weight_decay)
        # return torch.optim.AdamW(self.model.classifier[-1].parameters(), lr=learning_rate, weight_decay=weight_decay)

# %%
model = torch.nn.Sequential(
    torch.nn.Conv2d(in_channels=3, out_channels=width, kernel_size=3, stride=2, padding=1),
    torch.nn.ReLU(),
    torch.nn.BatchNorm2d(width),
    torch.nn.Conv2d(in_channels=width, out_channels=width, kernel_size=3, stride=2, padding=1),
    torch.nn.ReLU(),
    torch.nn.BatchNorm2d(width),
    torch.nn.Conv2d(in_channels=width, out_channels=width, kernel_size=3, stride=2, padding=1),
    torch.nn.ReLU(),
    torch.nn.BatchNorm2d(width),
    torch.nn.AdaptiveAvgPool2d(output_size=1),
    torch.nn.Flatten(),
    torch.nn.Linear(in_features=width, out_features=num_classes),
)

# %%
logger = pl.loggers.TensorBoardLogger("logs/", name="insurance_regression_logs")

# %%
baseline_model = ImageClassifier(model)

checkpoint_callback = pl.callbacks.ModelCheckpoint(monitor="val_acc", mode="max")
trainer = pl.Trainer(
    max_epochs=num_epochs_baseline,
    precision="16-mixed", #gyorsabb így mintha 32 bites floatot hsanzálnánk
    accelerator="gpu",
    devices=1,
    logger=logger,
    callbacks=[checkpoint_callback],
    log_every_n_steps=3
)
trainer.fit(baseline_model, datamodule)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:654: Checkpoint directory logs/insurance_regression_logs/version_3/checkpoints exists and is not empty.
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name               | Type                      | Params | Mode
# -------------------------------------------------------------------------
# 0 | model              | Sequential                | 76.2 K | eval
# 1 | accuracy           | MulticlassAccuracy        | 0      | train
# 2 | confusionmatrix    | MulticlassConfusionMatrix | 0      | train
# 3 | per_class_accuracy | MulticlassAccuracy        | 0      | train
# -------------------------------------------------------------------------
# 76.2 K    Trainable params
# 0         Non-trainable params
# 76.2 K    Total params
# 0.305     Total estimated model params size (MB)
# 3         Modules in train mode
# 13        Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (17) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.

# %%
trainer.validate(baseline_model, datamodule)
# Out:
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_acc          │    0.6428571343421936     │
# │      val_acc_class_0      │    0.5485714673995972     │
# │      val_acc_class_1      │    0.6571428775787354     │
# │      val_acc_class_2      │    0.6609523892402649     │
# │         val_loss          │    0.8068362474441528     │
# └───────────────────────────┴───────────────────────────┘
# [{'val_acc_class_0': 0.5485714673995972,
#   'val_acc_class_1': 0.6571428775787354,
#   'val_acc_class_2': 0.6609523892402649,
#   'val_loss': 0.8068362474441528,
#   'val_acc': 0.6428571343421936}]

# %%
trainer.test(baseline_model, datamodule)
# Out:
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.6666666865348816     │
# │         test_loss         │    0.7276346683502197     │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 0.7276346683502197, 'test_acc': 0.6666666865348816}]

# %% [markdown]
# Since we are performing multiclass classification we are aiming to maximize per class accuracy.

# %%
baseline_model.confusionmatrix.plot()
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='Predicted class', ylabel='True class'>)

# %%
baseline_model.per_class_accuracy.plot()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: ylabel='MulticlassAccuracy'>)
